# %%
pip install spectral
# Out:
# Requirement already satisfied: spectral in c:\users\prajes das\appdata\local\programs\python\python311\lib\site-packages (0.24)
# Requirement already satisfied: numpy in c:\users\prajes das\appdata\local\programs\python\python311\lib\site-packages (from spectral) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from spectral import *
import spectral.io.envi as envi

# %%
data_ref = envi.open('10a_101012-120551_refl_ss.hdr', '10a_101012-120551_refl_ss.dat')
data = np.array(data_ref.load())
print (data.shape) # wavelength1043-2486 nm in 230 bands
# Out:
# (285, 200, 230)

# %%
#image can't be displayed as RGB, the image already sliced in the Infrared range.
imshow(data, (0, 200, 220)) #in this case, I randomly select band to check if the image loaded properly
# Out:
# ImageView object:
#   Display bands       :  (0, 200, 220)
#   Interpolation       :  <default>
#   RGB data limits     :
#     R: [0.0, 0.5314581394195557]
#     G: [0.0, 0.561603307723999]
#     B: [0.0, 0.4880259037017822]

# %%
#after visual inspection, check the reflectance spectrum inside the pixel.
spectrum = data[100,100,:]
plt.plot(spectrum)
plt.show()

#please note that the wavelength hasn't assigned to the data, 0-230 bands represent the wavelength of 1043-2486
#the wavelength index will be assigned later

# %% [markdown]
# # Mineral Mapping using KMEANS
# As the image shape is transformed into two dimension, we are losing the spatial correlation of each pixel. In this method, we ignore the influence of the surrounding pixel and cluster them using the reflectance spectrum similarity.

# %%
from sklearn.cluster import KMeans

# %%
pixels = data.reshape((57000, 230))
print (pixels.shape)
# Out:
# (57000, 230)

# %%
imagedf=pd.DataFrame(pixels)

# %%
def optimise_k_means(data, max_k):
    means = []
    inertias = []
    
    for k in range(1,max_k):
        kmeans = KMeans(n_clusters=k)
        kmeans.fit(data)
        means.append(k)
        inertias.append(kmeans.inertia_)
    return means, inertias

# %%
means, inertias= optimise_k_means(imagedf, 10)

plt.plot(means, inertias, 'o-')
plt.xlabel("Number of Clusters")
plt.ylabel("Inertia")
plt.show()

# %% [markdown]
# According to the K-Means inertia, clustering the data into 5 classes (based on the reference information) is acceptable. In this case we add one more class, as the background of the image is also classified.

# %%
kmeans = KMeans(n_clusters=5)
kmeans.fit(imagedf)
imagedf['minerals'] = kmeans.labels_

# %%
imagenpy=imagedf.to_numpy()
print (imagenpy.shape)
# Out:
# (57000, 231)

# %%
classified=imagenpy.reshape(285, 200, 231)

# %%
MinMapKmeans=classified[:, :, 230]

# %%
plt.imshow(MinMapKmeans, cmap=plt.cm.get_cmap('viridis',4))
plt.colorbar()
# Out:
# C:\Users\PRAJES DAS\AppData\Local\Temp\ipykernel_20068\29803211.py:1: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   plt.imshow(MinMapKmeans, cmap=plt.cm.get_cmap('viridis',4))

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# Step 1: Load your mineral mapping result (GeoJSON)
gdf = gpd.read_file('/mnt/data/adf312ed-fa6c-4bec-8683-3b295a861bb8.geojson')

# Step 2: Inspect the columns (to see which minerals were mapped)
print(gdf.columns)

# Step 3: Plot the mineral mapping
fig, ax = plt.subplots(figsize=(12, 8))
gdf.plot(column='mineral', cmap='Set1', legend=True, ax=ax, edgecolor='black')  # Replace 'mineral' with the actual column name
plt.title("Mineral Mapping Result")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 import geopandas as gpd
#       2 import matplotlib.pyplot as plt
#       4 # Step 1: Load your mineral mapping result (GeoJSON)
#
# ModuleNotFoundError: No module named 'geopandas'

# %% [markdown]
# ### Mineral Naming
# According to the reference, the mineral occured in this rock are: Tourmaline, Muscovite and Illite (Normal and High Crystalline).
# Spectral library from John Hopkins University was used to define the mineralogy. However, the different spectral resolution is ignored in this case. Visual comparison on the absorption features is the deciding factor in the classes naming process.

# %%
#Helper Functions
def loadJHU(JHU):
    Mineral=pd.read_excel(JHU, header = 0)
    Mineral=Mineral[(Mineral.Wavelength >= 1.043) & (Mineral.Wavelength <= 2.486)]
    Mineral.set_index('Wavelength', drop=True, inplace=True)
    return Mineral

def wavelengthAssignment(minWave, maxWave, totalBand):
    step=(maxWave-minWave)/totalBand
    wavelength=[]
    i=minWave
    while i < maxWave :
        i=round(i+step, 1)
        wavelength.append(i)
    wavelength=[x for x in wavelength if x<maxWave]
    return wavelength

# %%
#load the spectral library
Tourmaline=loadJHU('tourmalineJHU.xlsx')
Muscovite=loadJHU('MuscoviteJHU.xlsx')
Illite=loadJHU('IlliteJHU.xlsx')
minerals=[Tourmaline, Muscovite, Illite]
mineralsName=["Tourmaline", "Muscovite", "Illite"]
fig,axes = plt.subplots(1,3,figsize=(15,5))
for i in range (-1,2, 1):
    axes[i].plot(minerals[i])
    axes[i].set_title(str(mineralsName[i]),fontsize=15)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[19], line 11
#       8     df = pd.read_excel(filepath)
#       9     return df
# ---> 11 Tourmaline = loadJHU("tourmalineJHU.xlsx")
#      12 Muscovite = loadJHU("MuscoviteJHU.xlsx")
#      13 Illite = loadJHU("IlliteJHU.xlsx")
#
# Cell In[19], line 8, in loadJHU(filepath)
#       7 def loadJHU(filepath):
# ----> 8     df = pd.read_excel(filepath)
#       9     return df
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_base.py:1550, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1548     ext = "xls"
#    1549 else:
# -> 1550     ext = inspect_excel_format(
#    1551         content_or_path=path_or_buffer, storage_options=storage_options
#    1552     )
#    1553     if ext is None:
#    1554         raise ValueError(
#    1555             "Excel file format cannot be determined, you must specify "
#    1556             "an engine manually."
#    1557         )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_base.py:1402, in inspect_excel_format(content_or_path, storage_options)
#    1399 if isinstance(content_or_path, bytes):
#    1400     content_or_path = BytesIO(content_or_path)
# -> 1402 with get_handle(
#    1403     content_or_path, "rb", storage_options=storage_options, is_text=False
#    1404 ) as handle:
#    1405     stream = handle.handle
#    1406     stream.seek(0)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\common.py:882, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#    (...)    878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
# --> 882         handle = open(handle, ioargs.mode)
#     883     handles.append(handle)
#     885 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'tourmalineJHU.xlsx'

# %% [markdown]
# By ignoring the spectral resolution and the reflectance value, the absorption features indicator for each minerals are summarized below:
#
#
# Illite and muscovite has very similar absorption features, the ratio of water absorption features in 1900nm and AlOH at 2200 nm were used to distinguish the different (indicaty the crystalinity degree). Note that Muscovite clearly shown higher ratio of absorption feature in both wavelength range compared to Illite.

# %%
import plotly.express as px
fig = px.imshow(classified[:, :, 230], color_continuous_scale='viridis')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 import plotly.express as px
#       2 fig = px.imshow(classified[:, :, 230], color_continuous_scale='viridis')
#       3 fig.show()
#
# ModuleNotFoundError: No module named 'plotly'

# %% [markdown]
# ### Class 1
# NOTES: The result of KMeans indicate that the background image as class 1. As the class 0 is located inside the image, the class 0 selected as the representative of the class 1.

# %%
wave=wavelengthAssignment(1043, 2486, 230)
spectrum1 = data[94,162,:] #the y, x, and the data
xlabel=[]
for x in range (0,230, 30):
    xlabel.append(wave[x])

fig,axes = plt.subplots(1,4,figsize=(15,5))
for i in range (0,3, 1):
    axes[i].plot(minerals[i])
    axes[i].set_title(str(mineralsName[i]),fontsize=15)
    
axes[3].plot (spectrum1)
axes[3].set_xticklabels(xlabel, rotation=20)
axes[3].set_title('Class 1', fontsize=15)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 9
#       7 fig,axes = plt.subplots(1,4,figsize=(15,5))
#       8 for i in range (0,3, 1):
# ----> 9     axes[i].plot(minerals[i])
#      10     axes[i].set_title(str(mineralsName[i]),fontsize=15)
#      12 axes[3].plot (spectrum1)
#
# NameError: name 'minerals' is not defined

# %% [markdown]
# ### Class 2

# %%
wave=wavelengthAssignment(1043, 2486, 230)
spectrum2 = data[119,24,:] #the y, x, and the data
xlabel=[]
for x in range (0,230, 30):
    xlabel.append(wave[x])

fig,axes = plt.subplots(1,4,figsize=(15,5))
for i in range (0,3, 1):
    axes[i].plot(minerals[i])
    axes[i].set_title(str(mineralsName[i]),fontsize=15)
    
axes[3].plot (spectrum2)
axes[3].set_xticklabels(xlabel, rotation=20)
axes[3].set_title('Class 2', fontsize=15)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 9
#       7 fig,axes = plt.subplots(1,4,figsize=(15,5))
#       8 for i in range (0,3, 1):
# ----> 9     axes[i].plot(minerals[i])
#      10     axes[i].set_title(str(mineralsName[i]),fontsize=15)
#      12 axes[3].plot (spectrum2)
#
# NameError: name 'minerals' is not defined

# %% [markdown]
# ### Class 3

# %%
wave=wavelengthAssignment(1043, 2486, 230)
spectrum3 = data[177,62,:] #the y, x, and the data
xlabel=[]
for x in range (0,230, 30):
    xlabel.append(wave[x])

fig,axes = plt.subplots(1,4,figsize=(15,5))
for i in range (0,3, 1):
    axes[i].plot(minerals[i])
    axes[i].set_title(str(mineralsName[i]),fontsize=15)
    
axes[3].plot (spectrum3)
axes[3].set_xticklabels(xlabel, rotation=20)
axes[3].set_title('Class 3', fontsize=15)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 9
#       7 fig,axes = plt.subplots(1,4,figsize=(15,5))
#       8 for i in range (0,3, 1):
# ----> 9     axes[i].plot(minerals[i])
#      10     axes[i].set_title(str(mineralsName[i]),fontsize=15)
#      12 axes[3].plot (spectrum3)
#
# NameError: name 'minerals' is not defined

# %% [markdown]
# ### Class 4

# %%
wave=wavelengthAssignment(1043, 2486, 230)
spectrum4 = data[115,120,:] #the y, x, and the data
xlabel=[]
for x in range (0,230, 30):
    xlabel.append(wave[x])

fig,axes = plt.subplots(1,4,figsize=(15,5))
for i in range (0,3, 1):
    axes[i].plot(minerals[i])
    axes[i].set_title(str(mineralsName[i]),fontsize=15)
    
axes[3].plot (spectrum4)
axes[3].set_xticklabels(xlabel, rotation=20)
axes[3].set_title('Class 4', fontsize=15)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 9
#       7 fig,axes = plt.subplots(1,4,figsize=(15,5))
#       8 for i in range (0,3, 1):
# ----> 9     axes[i].plot(minerals[i])
#      10     axes[i].set_title(str(mineralsName[i]),fontsize=15)
#      12 axes[3].plot (spectrum4)
#
# NameError: name 'minerals' is not defined

# %%
#plot the 3 similar minerals to distinguish between the muscovite and illite
plt.plot(spectrum1, label="mineral 1")
plt.plot(spectrum2, label="mineral 2")
plt.plot(spectrum4, label="mineral 4")
plt.legend()
plt.show()

# %% [markdown]
# ## Mineral Map
# To conclude:
# Mineral 1 is representing Illite HX (high crystalinity)
# Mineral 2 is representing Muscovite
# Mineral 3 is representing Tourmaline
# Mineral 4 is representing Illite (Low cristalinity)

# %%
Mineralogy= {1: "Illite HX",
            2: "Muscovite",
            3: "Tourmaline",
            4: "Illite"}

imagedf['mineralogy']=imagedf['minerals'].map(Mineralogy) #assign the mineralogy into the dataframe

# %%
#create pickle
imagedf.to_pickle("./MinMapKmeans.pkl")

# %% [markdown]
# # Mineral Mapping using PCA

# %%
from sklearn.decomposition import PCA
pca = PCA().fit(imagedf)
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance')
plt.xlim([0,10])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 2
#       1 from sklearn.decomposition import PCA
# ----> 2 pca = PCA().fit(imagedf)
#       3 plt.plot(np.cumsum(pca.explained_variance_ratio_))
#       4 plt.xlabel('number of components')
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\decomposition\_pca.py:442, in PCA.fit(self, X, y)
#     424 @_fit_context(prefer_skip_nested_validation=True)
#     425 def fit(self, X, y=None):
#     426     """Fit the model with X.
#     427
#     428     Parameters
#    (...)    440         Returns the instance itself.
#     441     """
# --> 442     self._fit(X)
#     443     return self
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\decomposition\_pca.py:505, in PCA._fit(self, X)
#     495     raise ValueError(
#     496         "PCA with svd_solver='arpack' is not supported for Array API inputs."
#     497     )
#     499 # Validate the data, without ever forcing a copy as any solver that
#     500 # supports sparse input data and the `covariance_eigh` solver are
#     501 # written in a way to avoid the need for any inplace modification of
#     502 # the input data contrary to the other solvers.
#     503 # The copy will happen
#     504 # later, only if needed, once the solver negotiation below is done.
# --> 505 X = validate_data(
#     506     self,
#     507     X,
#     508     dtype=[xp.float64, xp.float32],
#     509     force_writeable=True,
#     510     accept_sparse=("csr", "csc"),
#     511     ensure_2d=True,
#     512     copy=False,
#     513 )
#     514 self._fit_svd_solver = self.svd_solver
#     515 if self._fit_svd_solver == "auto" and issparse(X):
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2919, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2835 def validate_data(
#    2836     _estimator,
#    2837     /,
#    (...)   2843     **check_params,
#    2844 ):
#    2845     """Validate input data and set or check feature names and counts of the input.
#    2846
#    2847     This helper function should be used in an estimator that requires input
#    (...)   2917         validated.
#    2918     """
# -> 2919     _check_feature_names(_estimator, X, reset=reset)
#    2920     tags = get_tags(_estimator)
#    2921     if y is None and tags.target_tags.required:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2715, in _check_feature_names(estimator, X, reset)
#    2688 """Set or check the `feature_names_in_` attribute of an estimator.
#    2689
#    2690 .. versionadded:: 1.0
#    (...)   2711        should set `reset=False`.
#    2712 """
#    2714 if reset:
# -> 2715     feature_names_in = _get_feature_names(X)
#    2716     if feature_names_in is not None:
#    2717         estimator.feature_names_in_ = feature_names_in
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2417, in _get_feature_names(X)
#    2415 # mixed type of string and non-string is not supported
#    2416 if len(types) > 1 and "str" in types:
# -> 2417     raise TypeError(
#    2418         "Feature names are only supported if all input features have string names, "
#    2419         f"but your input has {types} as feature name / column name types. "
#    2420         "If you want feature names to be stored and validated, you must convert "
#    2421         "them all to strings, by using X.columns = X.columns.astype(str) for "
#    2422         "example. Otherwise you can remove feature / column names from your input "
#    2423         "data, or convert them all to a non-string data type."
#    2424     )
#    2426 # Only feature names of all strings are supported
#    2427 if len(types) == 1 and types[0] == "str":
#
# TypeError: Feature names are only supported if all input features have string names, but your input has ['int', 'str'] as feature name / column name types. If you want feature names to be stored and validated, you must convert them all to strings, by using X.columns = X.columns.astype(str) for example. Otherwise you can remove feature / column names from your input data, or convert them all to a non-string data type.

# %%
pca = PCA(n_components=2)
test=pca.fit_transform(imagedf)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 2
#       1 pca = PCA(n_components=2)
# ----> 2 test=pca.fit_transform(imagedf)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_set_output.py:319, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     317 @wraps(f)
#     318 def wrapped(self, X, *args, **kwargs):
# --> 319     data_to_wrap = f(self, X, *args, **kwargs)
#     320     if isinstance(data_to_wrap, tuple):
#     321         # only wrap the first output for cross decomposition
#     322         return_tuple = (
#     323             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     324             *data_to_wrap[1:],
#     325         )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\decomposition\_pca.py:468, in PCA.fit_transform(self, X, y)
#     445 @_fit_context(prefer_skip_nested_validation=True)
#     446 def fit_transform(self, X, y=None):
#     447     """Fit the model with X and apply the dimensionality reduction on X.
#     448
#     449     Parameters
#    (...)    466     C-ordered array, use 'np.ascontiguousarray'.
#     467     """
# --> 468     U, S, _, X, x_is_centered, xp = self._fit(X)
#     469     if U is not None:
#     470         U = U[:, : self.n_components_]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\decomposition\_pca.py:505, in PCA._fit(self, X)
#     495     raise ValueError(
#     496         "PCA with svd_solver='arpack' is not supported for Array API inputs."
#     497     )
#     499 # Validate the data, without ever forcing a copy as any solver that
#     500 # supports sparse input data and the `covariance_eigh` solver are
#     501 # written in a way to avoid the need for any inplace modification of
#     502 # the input data contrary to the other solvers.
#     503 # The copy will happen
#     504 # later, only if needed, once the solver negotiation below is done.
# --> 505 X = validate_data(
#     506     self,
#     507     X,
#     508     dtype=[xp.float64, xp.float32],
#     509     force_writeable=True,
#     510     accept_sparse=("csr", "csc"),
#     511     ensure_2d=True,
#     512     copy=False,
#     513 )
#     514 self._fit_svd_solver = self.svd_solver
#     515 if self._fit_svd_solver == "auto" and issparse(X):
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2919, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2835 def validate_data(
#    2836     _estimator,
#    2837     /,
#    (...)   2843     **check_params,
#    2844 ):
#    2845     """Validate input data and set or check feature names and counts of the input.
#    2846
#    2847     This helper function should be used in an estimator that requires input
#    (...)   2917         validated.
#    2918     """
# -> 2919     _check_feature_names(_estimator, X, reset=reset)
#    2920     tags = get_tags(_estimator)
#    2921     if y is None and tags.target_tags.required:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2715, in _check_feature_names(estimator, X, reset)
#    2688 """Set or check the `feature_names_in_` attribute of an estimator.
#    2689
#    2690 .. versionadded:: 1.0
#    (...)   2711        should set `reset=False`.
#    2712 """
#    2714 if reset:
# -> 2715     feature_names_in = _get_feature_names(X)
#    2716     if feature_names_in is not None:
#    2717         estimator.feature_names_in_ = feature_names_in
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2417, in _get_feature_names(X)
#    2415 # mixed type of string and non-string is not supported
#    2416 if len(types) > 1 and "str" in types:
# -> 2417     raise TypeError(
#    2418         "Feature names are only supported if all input features have string names, "
#    2419         f"but your input has {types} as feature name / column name types. "
#    2420         "If you want feature names to be stored and validated, you must convert "
#    2421         "them all to strings, by using X.columns = X.columns.astype(str) for "
#    2422         "example. Otherwise you can remove feature / column names from your input "
#    2423         "data, or convert them all to a non-string data type."
#    2424     )
#    2426 # Only feature names of all strings are supported
#    2427 if len(types) == 1 and types[0] == "str":
#
# TypeError: Feature names are only supported if all input features have string names, but your input has ['int', 'str'] as feature name / column name types. If you want feature names to be stored and validated, you must convert them all to strings, by using X.columns = X.columns.astype(str) for example. Otherwise you can remove feature / column names from your input data, or convert them all to a non-string data type.

# %%
print (test.shape)
PCAclass=test.reshape(285, 200, 2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 print (test.shape)
#       2 PCAclass=test.reshape(285, 200, 2)
#
# NameError: name 'test' is not defined

# %%
fig,axes = plt.subplots(1,2,figsize=(25,20),sharex='all',
                        sharey='all')

for i in range (2):
    axes[i].imshow(PCAclass[:, :, i],cmap=plt.cm.get_cmap('viridis', 5))
    axes[i].set_title('PC '+str(i+1),fontsize=25)
    axes[i].axis('off')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 5
#       1 fig,axes = plt.subplots(1,2,figsize=(25,20),sharex='all',
#       2                         sharey='all')
#       4 for i in range (2):
# ----> 5     axes[i].imshow(PCAclass[:, :, i],cmap=plt.cm.get_cmap('viridis', 5))
#       6     axes[i].set_title('PC '+str(i+1),fontsize=25)
#       7     axes[i].axis('off')
#
# NameError: name 'PCAclass' is not defined

# %% [markdown]
# ### With the PCA, we can distinguish the variation in the image, and we can repeat the comparison with JHU library to d
